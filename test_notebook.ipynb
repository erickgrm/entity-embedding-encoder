# %%
import numpy as np
import pandas as pd
from ee_encoder import EntityEmbeddingEncoder

# %%
# Example dataset
X = pd.DataFrame([['x',0.4,0.7,'a'],['y',0.1,0.9,'b'], ['x',0.2,0.83,'b'], ['x',0.14,0.78,'b']])
y = pd.Series([-1, 0, 1,0])

# Load encoder, fit_transform X
enc =  EntityEmbeddingEncoder()
X_enc = enc.fit_transform(X,y)

# Print datasets
print('Original dataset\n', pd.concat((X,y),axis=1).values)
print('Encoded dataset\n', pd.concat((X_enc,y),axis=1).values)
# Out:
# Original dataset
#  [['x' 0.4 0.7 'a' -1]
#  ['y' 0.1 0.9 'b' 0]
#  ['x' 0.2 0.83 'b' 1]
#  ['x' 0.14 0.78 'b' 0]]
# Encoded dataset
#  [[ 0.20416686  0.40000001  0.69999999  0.25764892 -1.        ]
#  [ 0.67711693  0.1         0.89999998  0.69386578  0.        ]
#  [ 0.20416686  0.2         0.82999998  0.69386578  1.        ]
#  [ 0.20416686  0.14        0.77999997  0.69386578  0.        ]]

# %%
# Plot the model
enc.plot_model()
from IPython.display import Image
Image('model.png')
# Out:
# Plot saved as model.png. To display it in a Jupyter notebook, type:
# from IPython.display import Image
# Image('model.png')
